# %%
from pandas.plotting import lag_plot
import pandas as pd
import  numpy as np

# %%
# %matplotlib inline
data = pd.Series([1,2,3,4,5,6,7,8,9])
data = pd.Series(0.1*np.random.rand(100))

# %%
lag_plot(data)
## 2d scatter plot between y(t) -> y(t+1)
